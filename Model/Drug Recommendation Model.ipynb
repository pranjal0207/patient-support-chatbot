# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import pickle

# %%
df = pd.read_csv("../Data/Processed Data/Cleaned_Drug_Review_Dataset_Train.csv")
df
# Out:
#                         drugName                     condition  \
# 0                      valsartan  left ventricular dysfunction
# 1                     guanfacine                          adhd
# 2                         lybrel                 birth control
# 3                     ortho evra                 birth control
# 4       buprenorphine / naloxone             opiate dependence
# ...                          ...                           ...
# 160387                   campral            alcohol dependence
# 160388            metoclopramide               nausea/vomiting
# 160389                   orencia          rheumatoid arthritis
# 160390        thyroid desiccated           underactive thyroid
# 160391              lubiprostone         constipation, chronic
#
#                                                    review  rating  usefulCount
# 0       side effect take combination bystolic 5 mg fis...       9           27
# 1       son halfway fourth week intuniv became concern...       8          192
# 2       used take another oral contraceptive 21 pill c...       5           17
# 3       first time using form birth control im glad we...       8           10
# 4       suboxone completely turned life around feel he...       9           37
# ...                                                   ...     ...          ...
# 160387  wrote first report midoctober 2014 alcohol sin...      10          125
# 160388  given iv surgey immediately became anxious cou...       1           34
# 160389  limited improvement 4 month developed bad rash...       2           35
# 160390  ive thyroid medication 49 year spent first 38 ...      10           79
# 160391  ive chronic constipation adult life tried linz...       9          116
#
# [160392 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import pickle

# Text Preprocessing
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['review'])

# Recommendation System
model = NearestNeighbors(metric='cosine', algorithm='brute')
model.fit(tfidf_matrix)

# Save the model and TF-IDF vectorizer
with open('drug_recommendation_model.pkl', 'wb') as f:
    pickle.dump(model, f)

with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)
